# %% [markdown]
# # **Attention-ResUnet**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from skimage import io

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import Conv2D, Convolution2D, BatchNormalization, Activation, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, MaxPooling2D, AveragePooling2D, UpSampling2D, Dropout, ZeroPadding2D
from tensorflow.keras.layers import Add, Lambda, ReLU, LeakyReLU, concatenate

from warnings import filterwarnings
filterwarnings('ignore')
import random
from glob import glob
from IPython.display import display

# %% [markdown]
# # Prepare dataset

# %%
#Set Parameters
im_width = 256
im_height = 256

# %% [markdown]
# # **Load image's path and mask's path**

# %%
train_files = []
mask_files = glob('../input/lgg-mri-segmentation/kaggle_3m/*/*_mask*')

for i in mask_files:
    train_files.append(i.replace('_mask',''))

print(train_files[:10])
print(mask_files[:10])
# Out:
# ['../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_8.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_34.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_33.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_43.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_39.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_7.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_31.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_6.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_38.tif']
# ['../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_8_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_34_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_33_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_43_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_39_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_7_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_31_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_6_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_38_mask.tif']

# %% [markdown]
# # **Data Visualization**

# %%
#Lets plot some samples
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=train_files[i]
    msk_path=mask_files[i]
    img=cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %% [markdown]
# ## **Create data frame and split data on train set, validation set and test set**

# %%
df = pd.DataFrame(data={"filename": train_files, 'mask' : mask_files})
df_train, df_test = train_test_split(df,test_size = 0.1)
df_train, df_val = train_test_split(df_train,test_size = 0.2)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (2828, 2)
# (708, 2)
# (393, 2)

# %% [markdown]
# ## **Data genertator, data augmentation and adjust data**

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %% [markdown]
# ##**Model**

# %%
def conv_block(x, filter_size, size, dropout, batch_norm=False):
    """
    Convolutional Block
    """
    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv

# %%
def repeat_elem(tensor, rep):
    """
    Repeating elements along axis
    """
    return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),arguments={'repnum': rep})(tensor)

# %%
def res_conv_block(x, filter_size, size, dropout, batch_norm=False):
    '''
    Residual convolutional layer.
    conv - BN - Activation - conv - BN   
                                     - shortcut  - BN - shortcut+BN - Activation
    '''
    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('relu')(conv)
    
    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    shortcut = layers.Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)

    res_path = layers.add([shortcut, conv])
    res_path = layers.Activation('relu')(res_path)
    return res_path

# %% [markdown]
# <h3>Attention Blocks

# %%
def gating_signal(input, out_size, batch_norm=False):
    """
    Gating Signal
    resize the down layer feature map into the same dimension as the up layer feature map
    using 1x1 conv
    :return: the gating feature map with the same dimension of the up layer feature map
    """
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

# %%
def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

    # Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

    # Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

# %%
def Attention_ResUNet(input_shape, NUM_CLASSES=1, dropout_rate=0.0, batch_norm=True):
    '''
    Attention UNet    
    '''
    # network structure
    FILTER_NUM = 64 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters
    
    inputs = layers.Input(input_shape, dtype=tf.float32)

    # Downsampling layers
    # DownRes 1, convolution + pooling
    conv_128 = res_conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = res_conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = res_conv_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = res_conv_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5, convolution only
    conv_8 = res_conv_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers
    # UpRes 6, attention gated concatenation + upsampling + double residual convolution
    gating_16 = gating_signal(conv_8, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=3)
    up_conv_16 = res_conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7
    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(conv_32, gating_32, 4*FILTER_NUM)
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=3)
    up_conv_32 = res_conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=3)
    up_conv_64 = res_conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(conv_128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=3)
    up_conv_128 = res_conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  #Change to softmax for multichannel

    # Model integration
    model = tf.keras.Model(inputs, conv_final, name="Attention_UNet")
    return model

# %%
img_height = 256
img_width = 256
num_channels = 3

attResUnet = Attention_ResUNet((img_height, img_width, num_channels), NUM_CLASSES=1, dropout_rate=0.0, batch_norm=True)
# Out:
# 2022-07-01 06:45:18.070316: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-01 06:45:18.176895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-01 06:45:18.177736: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-01 06:45:18.179632: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-01 06:45:18.180018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-01 06:45:18.180966: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-01 06:45:18.181836: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-01 06:45:20.759675: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-01 06:45:20.760561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-01 06:45:20.761224: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-01 06:45:20.761802: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
attResUnet.summary()
# Out:
# Model: "Attention_UNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 64) 256         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256, 256, 64) 0           batch_normalization_2[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 64) 0           add[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 8320        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 128 147584      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 128 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 128 512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 128 0           batch_normalization_5[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 128 0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 256)  33024       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 256)  590080      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 256)  0           batch_normalization_8[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  131584      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2359808     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 512)  0           batch_normalization_11[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 1024) 4096        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 1024) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 1024) 525312      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 1024) 9438208     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 1024) 4096        conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 1024) 4096        conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 1024) 0           batch_normalization_14[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16,
           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 256, 256, 1)  65          activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 256, 256, 1)  4           conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 256, 256, 1)  0           batch_normalization_35[0][0]
# ==================================================================================================
# Total params: 39,090,377
# Trainable params: 39,068,871
# Non-trainable params: 21,506
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import backend as K
EPOCHS = 100
BATCH_SIZE = 16
learning_rate = 0.001

# %%
epsilon = 1e-5
smooth = 1

def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def focal_tversky(y_true,y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.75
    return K.pow((1-pt_1), gamma)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

# %%
# compling model and callbacks functions
adam = tf.keras.optimizers.Adam(learning_rate = learning_rate, epsilon = 0.1)
attResUnet.compile(optimizer = adam, 
                  loss = focal_tversky, 
                  metrics = [tversky]
                 )
#callbacks
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min', 
                              verbose=1, 
                              patience=30
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="./Model5_AttentionResUnet_BrainMriSeg.h5", 
                               verbose=1, 
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=(im_height, im_width))
    
val_gen = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
history = attResUnet.fit(train_gen, 
                  epochs = EPOCHS,
                  steps_per_epoch=len(df_train) / BATCH_SIZE,
                  validation_data = val_gen,
                  validation_steps=len(df_val) / BATCH_SIZE,
                  callbacks = [checkpointer, earlystopping, reduce_lr])
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# 2022-07-01 06:45:25.425994: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-07-01 06:45:32.648900: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 177/176 [==============================] - ETA: 0s - loss: 0.9603 - tversky: 0.0525Found 708 validated image filenames.
# Found 708 validated image filenames.
# 176/176 [==============================] - 183s 935ms/step - loss: 0.9603 - tversky: 0.0525 - val_loss: 0.9739 - val_tversky: 0.0356
#
# Epoch 00001: val_loss improved from inf to 0.97390, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 2/100
# 176/176 [==============================] - 139s 787ms/step - loss: 0.9552 - tversky: 0.0592 - val_loss: 0.9636 - val_tversky: 0.0496
#
# Epoch 00002: val_loss improved from 0.97390 to 0.96360, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 3/100
# 176/176 [==============================] - 140s 793ms/step - loss: 0.9532 - tversky: 0.0618 - val_loss: 0.9551 - val_tversky: 0.0587
#
# Epoch 00003: val_loss improved from 0.96360 to 0.95513, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 4/100
# 176/176 [==============================] - 140s 794ms/step - loss: 0.9521 - tversky: 0.0632 - val_loss: 0.9509 - val_tversky: 0.0671
#
# Epoch 00004: val_loss improved from 0.95513 to 0.95092, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch
saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 34/100
# 176/176 [==============================] - 140s 790ms/step - loss: 0.8878 - tversky: 0.1460 - val_loss: 0.8836 - val_tversky: 0.1523
#
# Epoch 00034: val_loss did not improve from 0.88302
# Epoch 35/100
# 176/176 [==============================] - 140s 794ms/step - loss: 0.8804 - tversky: 0.1555 - val_loss: 0.8742 - val_tversky: 0.1638
#
# Epoch 00035: val_loss improved from 0.88302 to 0.87425, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 36/100
# 176/176 [==============================] - 140s 791ms/step - loss: 0.8733 - tversky: 0.1644 - val_loss: 0.8621 - val_tversky: 0.1764
#
# Epoch 00036: val_loss improved from 0.87425 to 0.86205, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 37/100
# 176/176 [==============================] - 140s 794ms/step - loss: 0.8654 - tversky: 0.1746 - val_loss: 0.8736 - val_tversky: 0.1630
#
# Epoch 00037: val_loss did not improve from 0.86205
# Epoch 38/100
# 176/176 [==============================] - 141s 801ms/step - loss: 0.8565 - tversky: 0.1856 - val_loss: 0.8556 - val_tversky: 0.1835
#
# Epoch 00038: val_loss improved from 0.86205 to 0.85561, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 39/100
# 176/176 [==============================] - 140s 792ms/step - loss: 0.8472 - tversky: 0.1975 - val_loss: 0.8351 - val_tversky: 0.2134
#
# Epoch 00039: val_loss improved from 0.85561 to 0.83509, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 40/100
# 176/176 [==============================] - 143s 810ms/step - loss: 0.8403 - tversky: 0.2062 - val_loss: 0.8285 - val_tversky: 0.2191
#
# Epoch 00040: val_loss improved from 0.83509 to 0.82846, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 41/100
# 176/176 [==============================] - 141s 800ms/step - loss: 0.8270 - tversky: 0.2228 - val_loss: 0.8146 - val_tversky: 0.2344
#
# Epoch 00041: val_loss improved from 0.82846 to 0.81461, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 42/100
# 176/176 [==============================] - 143s 811ms/step - loss: 0.8162 - tversky: 0.2357 - val_loss: 0.8181 - val_tversky: 0.2307
#
# Epoch 00042: val_loss did not improve from 0.81461
# Epoch 43/100
# 176/176 [==============================] - 145s 819ms/step - loss: 0.8048 - tversky: 0.2499 - val_loss: 0.7897 - val_tversky: 0.2704
#
# Epoch 00043: val_loss improved from 0.81461 to 0.78969, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 44/100
# 176/176 [==============================] - 143s 812ms/step - loss: 0.7922 - tversky: 0.2649 - val_loss: 0.7824 - val_tversky: 0.2726
#
# Epoch 00044: val_loss improved from 0.78969 to 0.78245, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 45/100
# 176/176 [==============================] - 145s 823ms/step - loss: 0.7770 - tversky: 0.2837 - val_loss: 0.7733 - val_tversky: 0.2842
#
# Epoch 00045: val_loss improved from 0.78245 to 0.77330, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 46/100
# 176/176 [==============================] - 143s 808ms/step - loss: 0.7612 - tversky: 0.3028 - val_loss: 0.7477 - val_tversky: 0.3165
#
# Epoch 00046: val_loss improved from 0.77330 to 0.74775, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 47/100
# 176/176 [==============================] - 143s 811ms/step - loss: 0.7443 - tversky: 0.3228 - val_loss: 0.7351 - val_tversky: 0.3322
#
# Epoch 00047: val_loss improved from 0.74775 to 0.73513, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 48/100
# 176/176 [==============================] - 145s 823ms/step - loss: 0.7251 - tversky: 0.3456 - val_loss: 0.7456 - val_tversky: 0.3193
#
# Epoch 00048: val_loss did not improve from 0.73513
# Epoch 49/100
# 176/176 [==============================] - 145s 824ms/step - loss: 0.7072 - tversky: 0.3670 - val_loss: 0.6914 - val_tversky: 0.3792
#
# Epoch 00049: val_loss improved from 0.73513 to 0.69136, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 50/100
# 176/176 [==============================] - 147s 833ms/step - loss: 0.6826 - tversky: 0.3960 - val_loss: 0.6760 - val_tversky: 0.4093
#
# Epoch 00050: val_loss improved from 0.69136 to 0.67604, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 51/100
# 176/176 [==============================] - 146s 824ms/step - loss: 0.6714 - tversky: 0.4090 - val_loss: 0.6675 - val_tversky: 0.4149
#
# Epoch 00051: val_loss improved from 0.67604 to 0.66746, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 52/100
# 176/176 [==============================] - 147s 831ms/step - loss: 0.6470 - tversky: 0.4369 - val_loss: 0.6554 - val_tversky: 0.4326
#
# Epoch 00052: val_loss improved from 0.66746 to 0.65544, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 53/100
# 176/176 [==============================] - 147s 834ms/step - loss: 0.6335 - tversky: 0.4520 - val_loss: 0.6204 - val_tversky: 0.4679
#
# Epoch 00053: val_loss improved from 0.65544 to 0.62040, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 54/100
# 176/176 [==============================] - 147s 834ms/step - loss: 0.6111 - tversky: 0.4765 - val_loss: 0.6349 - val_tversky: 0.4534
#
# Epoch 00054: val_loss did not improve from 0.62040
# Epoch 55/100
# 176/176 [==============================] - 146s 828ms/step - loss: 0.5940 - tversky: 0.4957 - val_loss: 0.5909 - val_tversky: 0.4921
#
# Epoch 00055: val_loss improved from 0.62040 to 0.59089, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 56/100
# 176/176 [==============================] - 146s 827ms/step - loss: 0.5749 - tversky: 0.5172 - val_loss: 0.5326 - val_tversky: 0.5569
#
# Epoch 00056: val_loss improved from 0.59089 to 0.53264, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 57/100
# 176/176 [==============================] - 145s 819ms/step - loss: 0.5545 - tversky: 0.5394 - val_loss: 0.6204 - val_tversky: 0.4645
#
# Epoch 00057: val_loss did not improve from 0.53264
# Epoch 58/100
# 176/176 [==============================] - 146s 828ms/step - loss: 0.5321 - tversky: 0.5649 - val_loss: 0.5111 - val_tversky: 0.5771
#
# Epoch 00058: val_loss improved from 0.53264 to 0.51110, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 59/100
# 176/176 [==============================] - 146s 827ms/step - loss: 0.5104 - tversky: 0.5876 - val_loss: 0.5352 - val_tversky: 0.5616
#
# Epoch 00059: val_loss did not improve from 0.51110
# Epoch 60/100
# 176/176 [==============================] - 145s 822ms/step - loss: 0.5070 - tversky: 0.5898 - val_loss: 0.4831 - val_tversky: 0.6188
#
# Epoch 00060: val_loss improved from 0.51110 to 0.48308, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 61/100
# 176/176 [==============================] - 143s 810ms/step - loss: 0.4914 - tversky: 0.6065 - val_loss: 0.5122 - val_tversky: 0.5773
#
# Epoch 00061: val_loss did not improve from 0.48308
# Epoch 62/100
# 176/176 [==============================] - 145s 818ms/step - loss: 0.4734 - tversky: 0.6250 - val_loss: 0.4534 - val_tversky: 0.6457
#
# Epoch 00062: val_loss improved from 0.48308 to 0.45344, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 63/100
# 176/176 [==============================] - 143s 809ms/step - loss: 0.4501 - tversky: 0.6498 - val_loss: 0.4801 - val_tversky: 0.6084
#
# Epoch 00063: val_loss did not improve from 0.45344
# Epoch 64/100
# 176/176 [==============================] - 144s 816ms/step - loss: 0.4443 - tversky: 0.6553 - val_loss: 0.5160 - val_tversky: 0.5838
#
# Epoch 00064: val_loss did not improve from 0.45344
# Epoch 65/100
# 176/176 [==============================] - 144s 816ms/step - loss: 0.4201 - tversky: 0.6803 - val_loss: 0.4271 - val_tversky: 0.6732
#
# Epoch 00065: val_loss improved from 0.45344 to 0.42713, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 66/100
# 176/176 [==============================] - 144s 815ms/step - loss: 0.4050 - tversky: 0.6954 - val_loss: 0.3978 - val_tversky: 0.6960
#
# Epoch 00066: val_loss improved from 0.42713 to 0.39776, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 67/100
# 176/176 [==============================] - 145s 822ms/step - loss: 0.3935 - tversky: 0.7049 - val_loss: 0.3860 - val_tversky: 0.7137
#
# Epoch 00067: val_loss improved from 0.39776 to 0.38599, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 68/100
# 176/176 [==============================] - 144s 816ms/step - loss: 0.3695 - tversky: 0.7303 - val_loss: 0.3739 - val_tversky: 0.7140
#
# Epoch 00068: val_loss improved from 0.38599 to 0.37395, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 69/100
# 176/176 [==============================] - 144s 817ms/step - loss: 0.3753 - tversky: 0.7220 - val_loss: 0.3771 - val_tversky: 0.7194
#
# Epoch 00069: val_loss did not improve from 0.37395
# Epoch 70/100
# 176/176 [==============================] - 143s 809ms/step - loss: 0.3549 - tversky: 0.7441 - val_loss: 0.3787 - val_tversky: 0.7143
#
# Epoch 00070: val_loss did not improve from 0.37395
# Epoch 71/100
# 176/176 [==============================] - 142s 807ms/step - loss: 0.3542 - tversky: 0.7433 - val_loss: 0.3453 - val_tversky: 0.7573
#
# Epoch 00071: val_loss improved from 0.37395 to 0.34532, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 72/100
# 176/176 [==============================] - 143s 812ms/step - loss: 0.3384 - tversky: 0.7594 - val_loss: 0.3317 - val_tversky: 0.7683
#
# Epoch 00072: val_loss improved from 0.34532 to 0.33165, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 73/100
# 176/176 [==============================] - 144s 813ms/step - loss: 0.3221 - tversky: 0.7749 - val_loss: 0.3390 - val_tversky: 0.7611
#
# Epoch 00073: val_loss did not improve from 0.33165
# Epoch 74/100
# 176/176 [==============================] - 143s 810ms/step - loss: 0.3264 - tversky: 0.7693 - val_loss: 0.3278 - val_tversky: 0.7563
#
# Epoch 00074: val_loss improved from 0.33165 to 0.32779, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 75/100
# 176/176 [==============================] - 143s 809ms/step - loss: 0.3108 - tversky: 0.7834 - val_loss: 0.3048 - val_tversky: 0.7916
#
# Epoch 00075: val_loss improved from 0.32779 to 0.30482, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 76/100
# 176/176 [==============================] - 144s 817ms/step - loss: 0.2956 - tversky: 0.7983 - val_loss: 0.3166 - val_tversky: 0.7666
#
# Epoch 00076: val_loss did not improve from 0.30482
# Epoch 77/100
# 176/176 [==============================] - 144s 818ms/step - loss: 0.2891 - tversky: 0.8036 - val_loss: 0.3093 - val_tversky: 0.7716
#
# Epoch 00077: val_loss did not improve from 0.30482
# Epoch 78/100
# 176/176 [==============================] - 145s 823ms/step - loss: 0.2797 - tversky: 0.8126 - val_loss: 0.2871 - val_tversky: 0.7924
#
# Epoch 00078: val_loss improved from 0.30482 to 0.28713, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 79/100
# 176/176 [==============================] - 144s 817ms/step - loss: 0.2840 - tversky: 0.8079 - val_loss: 0.3124 - val_tversky: 0.7869
#
# Epoch 00079: val_loss did not improve from 0.28713
# Epoch 80/100
# 176/176 [==============================] - 143s 811ms/step - loss: 0.2870 - tversky: 0.8062 - val_loss: 0.2891 - val_tversky: 0.8058
#
# Epoch 00080: val_loss did not improve from 0.28713
# Epoch 81/100
# 176/176 [==============================] - 145s 820ms/step - loss: 0.2803 - tversky: 0.8116 - val_loss: 0.2901 - val_tversky: 0.8006
#
# Epoch 00081: val_loss did not improve from 0.28713
# Epoch 82/100
# 176/176 [==============================] - 144s 813ms/step - loss: 0.2628 - tversky: 0.8280 - val_loss: 0.3156 - val_tversky: 0.7668
#
# Epoch 00082: val_loss did not improve from 0.28713
# Epoch 83/100
# 176/176 [==============================] - 144s 817ms/step - loss: 0.2712 - tversky: 0.8179 - val_loss: 0.4532 - val_tversky: 0.6521
#
# Epoch 00083: val_loss did not improve from 0.28713
# Epoch 84/100
# 176/176 [==============================] - 143s 807ms/step - loss: 0.2536 - tversky: 0.8347 - val_loss: 0.2595 - val_tversky: 0.8292
#
# Epoch 00084: val_loss improved from 0.28713 to 0.25948, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 85/100
# 176/176 [==============================] - 144s 816ms/step - loss: 0.2381 - tversky: 0.8499 - val_loss: 0.2633 - val_tversky: 0.8277
#
# Epoch 00085: val_loss did not improve from 0.25948
# Epoch 86/100
# 176/176 [==============================] - 143s 812ms/step - loss: 0.2448 - tversky: 0.8421 - val_loss: 0.2589 - val_tversky: 0.8332
#
# Epoch 00086: val_loss improved from 0.25948 to 0.25892, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 87/100
# 176/176 [==============================] - 144s 816ms/step - loss: 0.2444 - tversky: 0.8433 - val_loss: 0.2578 - val_tversky: 0.8335
#
# Epoch 00087: val_loss improved from 0.25892 to 0.25775, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 88/100
# 176/176 [==============================] - 146s 825ms/step - loss: 0.2419 - tversky: 0.8458 - val_loss: 0.2582 - val_tversky: 0.8313
#
# Epoch 00088: val_loss did not improve from 0.25775
# Epoch 89/100
# 176/176 [==============================] - 145s 823ms/step - loss: 0.2298 - tversky: 0.8551 - val_loss: 0.2343 - val_tversky: 0.8512
#
# Epoch 00089: val_loss improved from 0.25775 to 0.23427, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 90/100
# 176/176 [==============================] - 147s 833ms/step - loss: 0.2347 - tversky: 0.8515 - val_loss: 0.2615 - val_tversky: 0.8153
#
# Epoch 00090: val_loss did not improve from 0.23427
# Epoch 91/100
# 176/176 [==============================] - 145s 821ms/step - loss: 0.2524 - tversky: 0.8323 - val_loss: 0.2618 - val_tversky: 0.8295
#
# Epoch 00091: val_loss did not improve from 0.23427
# Epoch 92/100
# 176/176 [==============================] - 148s 838ms/step - loss: 0.2198 - tversky: 0.8637 - val_loss: 0.2661 - val_tversky: 0.8264
#
# Epoch 00092: val_loss did not improve from 0.23427
# Epoch 93/100
# 176/176 [==============================] - 148s 839ms/step - loss: 0.2158 - tversky: 0.8681 - val_loss: 0.2589 - val_tversky: 0.8173
#
# Epoch 00093: val_loss did not improve from 0.23427
# Epoch 94/100
# 176/176 [==============================] - 147s 830ms/step - loss: 0.2365 - tversky: 0.8483 - val_loss: 0.2324 - val_tversky: 0.8556
#
# Epoch 00094: val_loss improved from 0.23427 to 0.23235, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 95/100
# 176/176 [==============================] - 146s 828ms/step - loss: 0.2145 - tversky: 0.8686 - val_loss: 0.2294 - val_tversky: 0.8545
#
# Epoch 00095: val_loss improved from 0.23235 to 0.22945, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 96/100
# 176/176 [==============================] - 149s 842ms/step - loss: 0.2151 - tversky: 0.8676 - val_loss: 0.3428 - val_tversky: 0.7562
#
# Epoch 00096: val_loss did not improve from 0.22945
# Epoch 97/100
# 176/176 [==============================] - 148s 836ms/step - loss: 0.2364 - tversky: 0.8493 - val_loss: 0.2831 - val_tversky: 0.8111
#
# Epoch 00097: val_loss did not improve from 0.22945
# Epoch 98/100
# 176/176 [==============================] - 147s 833ms/step - loss: 0.2210 - tversky: 0.8617 - val_loss: 0.2119 - val_tversky: 0.8710
#
# Epoch 00098: val_loss improved from 0.22945 to 0.21188, saving model to ./Model5_AttentionResUnet_BrainMriSeg.h5
# Epoch 99/100
# 176/176 [==============================] - 147s 835ms/step - loss: 0.2064 - tversky: 0.8754 - val_loss: 0.2373 - val_tversky: 0.8490
#
# Epoch 00099: val_loss did not improve from 0.21188
# Epoch 100/100
# 176/176 [==============================] - 147s 830ms/step - loss: 0.1987 - tversky: 0.8808 - val_loss: 0.2346 - val_tversky: 0.8366
#
# Epoch 00100: val_loss did not improve from 0.21188

# %% [markdown]
# ## Model Evaluation

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'tversky', 'val_loss', 'val_tversky', 'lr'])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss']);
plt.plot(history.history['val_loss']);
plt.title("SEG Model focal tversky Loss");
plt.ylabel("focal tversky loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(history.history['tversky']);
plt.plot(history.history['val_tversky']);
plt.title("SEG Model tversky score");
plt.ylabel("tversky Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %% [markdown]
# ## Segmantation Model Performance

# %%
attResUnet = load_model("./Model5_AttentionResUnet_BrainMriSeg.h5",custom_objects={"focal_tversky":focal_tversky,"tversky":tversky,"tversky_loss":tversky_loss})

# %%
test_gen = train_generator(df_test, BATCH_SIZE, dict(), target_size=(im_height, im_width))
results = attResUnet.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 24/24 [==============================] - 8s 292ms/step - loss: 0.2304 - tversky: 0.8364

# %%
for i in range(30):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['filename'].iloc[index])
    img = cv2.resize(img ,(im_height, im_width))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred= attResUnet.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
