# %% [markdown]
# # **Mobilenet Unet**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from skimage import io

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import Conv2D, Convolution2D, BatchNormalization, Activation, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, MaxPooling2D, AveragePooling2D, UpSampling2D, Dropout, ZeroPadding2D
from tensorflow.keras.layers import Add, Lambda, ReLU, LeakyReLU, concatenate
from tensorflow.keras.applications import MobileNetV2

from warnings import filterwarnings
filterwarnings('ignore')
import random
from glob import glob
from IPython.display import display

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1
# 2022-06-30 06:34:19.313073: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 06:34:19.447604: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 06:34:19.448739: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# ### **Prepare dataset**

# %%
#Set Parameters
im_width = 256
im_height = 256

# %% [markdown]
# ### **Load image's path and mask's path**

# %%
train_files = []
mask_files = glob('../input/lgg-mri-segmentation/kaggle_3m/*/*_mask*')

for i in mask_files:
    train_files.append(i.replace('_mask',''))

print(train_files[:10])
print(mask_files[:10])
# Out:
# ['../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_8.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_34.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_33.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_43.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_39.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_7.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_31.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_6.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_38.tif']
# ['../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_8_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_34_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_33_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_43_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_39_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_7_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_31_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_6_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_38_mask.tif']

# %% [markdown]
# ### **Data Visualization**

# %%
#Lets plot some samples
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=train_files[i]
    msk_path=mask_files[i]
    img=cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %% [markdown]
# ### **Create data frame and split data on train set, validation set and test set**

# %%
df = pd.DataFrame(data={"filename": train_files, 'mask' : mask_files})
df_train, df_test = train_test_split(df,test_size = 0.1)
df_train, df_val = train_test_split(df_train,test_size = 0.2)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (2828, 2)
# (708, 2)
# (393, 2)

# %% [markdown]
# ### **Data genertator, data augmentation and adjust data**

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)

    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)

    for (img, mask) in train_gen:
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0

    return (img, mask)

# %% [markdown]
# ## **Model**

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip])
    x = conv_block(x, num_filters)

    return x

# %%
def build_mobilenetv2_unet(input_shape):
    """ Input """
    inputs = Input(shape=input_shape)

    """ Pre-trained MobileNetV2 """
    encoder = MobileNetV2(include_top=False, weights="imagenet",
        input_tensor=inputs, alpha=1.4)

    """ Encoder """
    s1 = encoder.get_layer("input_1").output                ## (512 x 512)
    s2 = encoder.get_layer("block_1_expand_relu").output    ## (256 x 256)
    s3 = encoder.get_layer("block_3_expand_relu").output    ## (128 x 128)
    s4 = encoder.get_layer("block_6_expand_relu").output    ## (64 x 64)

    """ Bridge """
    b1 = encoder.get_layer("block_13_expand_relu").output   ## (32 x 32)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)                         ## (64 x 64)
    d2 = decoder_block(d1, s3, 256)                         ## (128 x 128)
    d3 = decoder_block(d2, s2, 128)                         ## (256 x 256)
    d4 = decoder_block(d3, s1, 64)                          ## (512 x 512)

    """ Output """
    outputs = Conv2D(1, 1, padding="same")(d4)
    outputs = Activation('sigmoid')(outputs)

    model = Model(inputs, outputs, name="MobileNetV2_UNet")
    return model

# %%
mobile_unet = build_mobilenetv2_unet(input_shape=(256,256,3))
# Out:
# 2022-06-30 06:34:23.671238: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-30 06:34:23.671759: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 06:34:23.672968: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 06:34:23.674010: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 06:34:26.310510: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 06:34:26.311613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 06:34:26.312692: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 06:34:26.313675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.4_224_no_top.h5
# 17833984/17831080 [==============================] - 1s 0us/step
# 17842176/17831080 [==============================] - 1s 0us/step

# %%
mobile_unet.summary()
# Out:
# Model: "MobileNetV2_UNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 128, 128, 48) 1296        input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 128, 128, 48) 192         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 128, 128, 48) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 128, 128, 48) 432         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 128, 128, 48) 192         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 128, 128, 48) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 128, 128, 24) 1152        expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 128, 128, 24) 96          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 128, 128, 144 3456        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 128, 128, 144 576         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 128, 128, 144 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 129, 129, 144 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 64, 64, 144)  1296        block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 64, 64, 144)  576         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 64, 64, 144)  0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 64, 64, 32)   4608        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 64, 64, 32)   128         block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 64, 64, 192)  6144        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 64, 64, 192)  768         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 64, 64, 192)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 64, 64, 192)  1728        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 64, 64, 192)  768         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 64, 64, 192)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 64, 64, 32)   6144        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 64, 64, 32)   128         block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 64, 64, 32)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 64, 64, 192)  6144        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 64, 64, 192)  768         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 64, 64, 192)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 65, 65, 192)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 32, 32, 192)  1728        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 32, 32, 192)  768         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 32, 32, 192)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 32, 32, 48)   9216        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 32, 32, 48)   192         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 32, 32, 288)  13824       block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 32, 32, 288)  1152        block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 32, 32, 288)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 32, 32, 288)  2592        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 32, 32, 288)  1152        block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 32, 32, 288)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 32, 32, 48)   13824       block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 32, 32, 48)   192         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 32, 32, 48)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 32, 32, 288)  13824       block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 32, 32, 288)  1152        block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 32, 32, 288)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 32, 32, 288)  2592        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 32, 32, 288)  1152        block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 32, 32, 288)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 32, 32, 48)   13824       block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 32, 32, 48)   192         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 32, 32, 48)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 32, 32, 288)  13824       block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 32, 32, 288)  1152        block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 32, 32, 288)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 33, 33, 288)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 16, 16, 288)  2592        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 16, 16, 288)  1152        block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 16, 16, 288)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 16, 16, 88)   25344       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 16, 16, 88)   352         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 16, 16, 528)  46464       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 16, 16, 528)  2112        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 16, 16, 528)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 16, 16, 528)  4752        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 16, 16, 528)  2112        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 16, 16, 528)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 16, 16, 88)   46464       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 16, 16, 88)   352         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 16, 16, 88)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 16, 16, 528)  46464       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 16, 16, 528)  2112        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 16, 16, 528)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 16, 16, 528)  4752        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 16, 16, 528)  2112        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 16, 16, 528)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 16, 16, 88)   46464       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 16, 16, 88)   352         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 16, 16, 88)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 16, 16, 528)  46464       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 16, 16, 528)  2112        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 16, 16, 528)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 16, 16, 528)  4752        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 16, 16, 528)  2112        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 16, 16, 528)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 16, 16, 88)   46464       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 16, 16, 88)   352         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 16, 16, 88)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 16, 16, 528)  46464       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 16, 16, 528)  2112        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 16, 16, 528)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 16, 16, 528)  4752        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 16, 16, 528)  2112        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 16, 16, 528)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 16, 16, 136)  71808       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 16, 16, 136)  544         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 16, 16, 816)  110976      block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 16, 16, 816)  3264        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 16, 16, 816)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 16, 16, 816)  7344        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 16, 16, 816)  3264        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 16, 16, 816)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 16, 16, 136)  110976      block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 16, 16, 136)  544         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 16, 16, 136)  0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 16, 16, 816)  110976      block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 16, 16, 816)  3264        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 16, 16, 816)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 16, 16, 816)  7344        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 16, 16, 816)  3264        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 16, 16, 816)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 16, 16, 136)  110976      block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 16, 16, 136)  544         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 16, 16, 136)  0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 16, 16, 816)  110976      block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 16, 16, 816)  3264        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 16, 16, 816)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 512)  1671680     block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 800)  0           conv2d_transpose[0][0]
#                                                                  block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 512)  3686912     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 512)  2048        conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 512)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 512)  2359808     activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 512)  2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 512)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  524544      activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 448)  0           conv2d_transpose_1[0][0]
#                                                                  block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 256)  1032448     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 256)  590080      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 131200      activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 272 0           conv2d_transpose_2[0][0]
#                                                                  block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 128 313472      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 128 512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 128 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 147584      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 128 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 128 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 32832       activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 67) 0           conv2d_transpose_3[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 64) 38656       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256, 256, 64) 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 256, 256, 64) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 64) 36928       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256, 256, 64) 256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256, 256, 64) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 1)  65          activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 256, 1)  0           conv2d_8[0][0]
# ==================================================================================================
# Total params: 11,753,809
# Trainable params: 11,725,617
# Non-trainable params: 28,192
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import backend as K
EPOCHS = 100
BATCH_SIZE = 16
learning_rate = 0.001

# %%
epsilon = 1e-5
smooth = 1

def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def focal_tversky(y_true,y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    pt_1 = tversky(y_true, y_pred)
    gamma = 0.75
    return K.pow((1-pt_1), gamma)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

# %%
# compling model and callbacks functions
adam = tf.keras.optimizers.Adam(learning_rate = 0.001, epsilon = 0.1)
mobile_unet.compile(optimizer = adam,
                  loss = focal_tversky,
                  metrics = [tversky]
                 )
#callbacks
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=30
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="./Model10_Mobilennetv2Unet_BrainMriSeg.h5",
                               verbose=1,
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )

# %%
train_generator_args = dict(rescale=1.0/255.0,
                            rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=(im_height, im_width))

val_gen = train_generator(df_val, BATCH_SIZE,
                                dict(rescale=1.0/255.0),
                                target_size=(im_height, im_width))
history = mobile_unet.fit(train_gen,
                  epochs = EPOCHS,
                  steps_per_epoch=len(df_train) / BATCH_SIZE,
                  validation_data = val_gen,
                  validation_steps=len(df_val) / BATCH_SIZE,
                  callbacks = [checkpointer, earlystopping, reduce_lr])
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# 2022-06-30 06:34:32.875805: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-06-30 06:34:39.389771: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 177/176 [==============================] - ETA: 0s - loss: 0.9720 - tversky: 0.0372Found 708 validated image filenames.
# Found 708 validated image filenames.
# 176/176 [==============================] - 140s 709ms/step - loss: 0.9720 - tversky: 0.0372 - val_loss: 0.9736 - val_tversky: 0.0354
#
# Epoch 00001: val_loss improved from inf to 0.97357, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 2/100
# 176/176 [==============================] - 91s 518ms/step - loss: 0.9641 - tversky: 0.0475 - val_loss: 0.9706 - val_tversky: 0.0400
#
# Epoch 00002: val_loss improved from 0.97357 to 0.97064, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 3/100
# 176/176 [==============================] - 90s 511ms/step - loss: 0.9561 - tversky: 0.0580 - val_loss: 0.9655 - val_tversky: 0.0463
#
# Epoch 00003: val_loss improved from 0.97064 to 0.96553, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 4/100
# 176/176 [==============================] - 94s 531ms/step - loss: 0.9493 - tversky: 0.0668 - val_loss: 0.9586 - val_tversky: 0.0538
#
# Epoch 00004: val_loss improved from 0.96553 to 0.95861, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 5/100
# 176/176 [==============================] - 92s 520ms/step - loss: 0.9413 - tversky: 0.0774 - val_loss: 0.9491 - val_tversky: 0.0677
#
# Epoch 00005: val_loss improved from 0.95861 to 0.94906, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 6/100
# 176/176 [==============================] - 91s 515ms/step - loss: 0.9305 - tversky: 0.0912 - val_loss: 0.9336 - val_tversky: 0.0882
#
# Epoch 00006: val_loss improved from 0.94906 to 0.93359, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 7/100
# 176/176 [==============================] - 92s 523ms/step - loss: 0.9141 - tversky: 0.1125 - val_loss: 0.9191 - val_tversky: 0.1059
#
# Epoch 00007: val_loss improved from 0.93359 to 0.91912, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 8/100
# 176/176 [==============================] - 91s 516ms/step - loss: 0.8848 - tversky: 0.1503 - val_loss: 0.8871 - val_tversky: 0.1462
#
# Epoch 00008: val_loss improved from 0.91912 to 0.88709, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 9/100
# 176/176 [==============================] - 91s 518ms/step - loss: 0.8287 - tversky: 0.2204 - val_loss: 0.8827 - val_tversky: 0.1505
#
# Epoch 00009: val_loss improved from 0.88709 to 0.88270, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 10/100
# 176/176 [==============================] - 91s 517ms/step - loss: 0.7329 - tversky: 0.3350 - val_loss: 0.8363 - val_tversky: 0.2063
#
# Epoch 00010: val_loss improved from 0.88270 to 0.83626, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 11/100
# 176/176 [==============================] - 92s 520ms/step - loss: 0.6411 - tversky: 0.4420 - val_loss: 0.8131 - val_tversky: 0.2330
#
# Epoch 00011: val_loss improved from 0.83626 to 0.81313, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 12/100
# 176/176 [==============================] - 92s 524ms/step - loss: 0.5803 - tversky: 0.5092 - val_loss: 0.8751 - val_tversky: 0.1584
#
# Epoch 00012: val_loss did not improve from 0.81313
# Epoch 13/100
# 176/176 [==============================] - 93s 528ms/step - loss: 0.5258 - tversky: 0.5692 - val_loss: 0.7311 - val_tversky: 0.3331
#
# Epoch 00013: val_loss improved from 0.81313 to 0.73113, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 14/100
# 176/176 [==============================] - 91s 517ms/step - loss: 0.4657 - tversky: 0.6304 - val_loss: 0.5168 - val_tversky: 0.5705
#
# Epoch 00014: val_loss improved from 0.73113 to 0.51685, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 15/100
# 176/176 [==============================] - 91s 515ms/step - loss: 0.3835 - tversky: 0.7153 - val_loss: 0.4405 - val_tversky: 0.6494
#
# Epoch 00015: val_loss improved from 0.51685 to 0.44045, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 16/100
# 176/176 [==============================] - 93s 525ms/step - loss: 0.3196 - tversky: 0.7754 - val_loss: 0.3245 - val_tversky: 0.7729
#
# Epoch 00016: val_loss improved from 0.44045 to 0.32454, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 17/100
# 176/176 [==============================] - 93s 525ms/step - loss: 0.2723 - tversky: 0.8184 - val_loss: 0.2517 - val_tversky: 0.8355
#
# Epoch 00017: val_loss improved from 0.32454 to 0.25166, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 18/100
# 176/176 [==============================] - 91s 514ms/step - loss: 0.2543 - tversky: 0.8346 - val_loss: 0.2503 - val_tversky: 0.8403
#
# Epoch 00018: val_loss improved from 0.25166 to 0.25031, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 19/100
# 176/176 [==============================] - 91s 517ms/step - loss: 0.2370 - tversky: 0.8503 - val_loss: 0.2327 - val_tversky: 0.8539
#
# Epoch 00019: val_loss improved from 0.25031 to 0.23274, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 20/100
# 176/176 [==============================] - 91s 515ms/step - loss: 0.2311 - tversky: 0.8525 - val_loss: 0.2336 - val_tversky: 0.8484
#
# Epoch 00020: val_loss did not improve from 0.23274
# Epoch 21/100
# 176/176 [==============================] - 92s 521ms/step - loss: 0.2192 - tversky: 0.8639 - val_loss: 0.2787 - val_tversky: 0.8150
#
# Epoch 00021: val_loss did not improve from 0.23274
# Epoch 22/100
# 176/176 [==============================] - 92s 519ms/step - loss: 0.2116 - tversky: 0.8705 - val_loss: 0.2500 - val_tversky: 0.8408
#
# Epoch 00022: val_loss did not improve from 0.23274
# Epoch 23/100
# 176/176 [==============================] - 90s 512ms/step - loss: 0.2056 - tversky: 0.8757 - val_loss: 0.2317 - val_tversky: 0.8556
#
# Epoch 00023: val_loss improved from 0.23274 to 0.23169, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 24/100
# 176/176 [==============================] - 93s 527ms/step - loss: 0.2015 - tversky: 0.8787 - val_loss: 0.2043 - val_tversky: 0.8636
#
# Epoch 00024: val_loss improved from 0.23169 to 0.20426, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 25/100
# 176/176 [==============================] - 93s 526ms/step - loss: 0.1931 - tversky: 0.8854 - val_loss: 0.2260 - val_tversky: 0.8575
#
# Epoch 00025: val_loss did not improve from 0.20426
# Epoch 26/100
# 176/176 [==============================] - 93s 525ms/step - loss: 0.1917 - tversky: 0.8858 - val_loss: 0.2158 - val_tversky: 0.8670
#
# Epoch 00026: val_loss did not improve from 0.20426
# Epoch 27/100
# 176/176 [==============================] - 92s 520ms/step - loss: 0.1790 - tversky: 0.8972 - val_loss: 0.1974 - val_tversky: 0.8842
#
# Epoch 00027: val_loss improved from 0.20426 to 0.19737, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 28/100
# 176/176 [==============================] - 92s 522ms/step - loss: 0.1893 - tversky: 0.8880 - val_loss: 0.2796 - val_tversky: 0.8080
#
# Epoch 00028: val_loss did not improve from 0.19737
# Epoch 29/100
# 176/176 [==============================] - 91s 516ms/step - loss: 0.1833 - tversky: 0.8932 - val_loss: 0.1932 - val_tversky: 0.8873
#
# Epoch 00029: val_loss improved from 0.19737 to 0.19316, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 30/100
# 176/176 [==============================] - 93s 525ms/step - loss: 0.1768 - tversky: 0.8988 - val_loss: 0.1840 - val_tversky: 0.8933
#
# Epoch 00030: val_loss improved from 0.19316 to 0.18404, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 31/100
# 176/176 [==============================] - 92s 522ms/step - loss: 0.1782 - tversky: 0.8962 - val_loss: 0.2039 - val_tversky: 0.8650
#
# Epoch 00031: val_loss did not improve from 0.18404
# Epoch 32/100
# 176/176 [==============================] - 92s 524ms/step - loss: 0.1802 - tversky: 0.8946 - val_loss: 0.2053 - val_tversky: 0.8749
#
# Epoch 00032: val_loss did not improve from 0.18404
# Epoch 33/100
# 176/176 [==============================] - 93s 524ms/step - loss: 0.1648 - tversky: 0.9085 - val_loss: 0.1872 - val_tversky: 0.8908
#
# Epoch 00033: val_loss did not improve from 0.18404
# Epoch 34/100
# 176/176 [==============================] - 92s 519ms/step - loss: 0.1670 - tversky: 0.9050 - val_loss: 0.2004 - val_tversky: 0.8689
#
# Epoch 00034: val_loss did not improve from 0.18404
# Epoch 35/100
# 176/176 [==============================] - 91s 515ms/step - loss: 0.1682 - tversky: 0.9046 - val_loss: 0.2074 - val_tversky: 0.8709
#
# Epoch 00035: val_loss did not improve from 0.18404
# Epoch 36/100
# 176/176 [==============================] - 92s 520ms/step - loss: 0.1566 - tversky: 0.9136 - val_loss: 0.1976 - val_tversky: 0.8672
#
# Epoch 00036: val_loss did not improve from 0.18404
# Epoch 37/100
# 176/176 [==============================] - 93s 525ms/step - loss: 0.1651 - tversky: 0.9053 - val_loss: 0.1944 - val_tversky: 0.8733
#
# Epoch 00037: val_loss did not improve from 0.18404
# Epoch 38/100
# 176/176 [==============================] - 93s 529ms/step - loss: 0.1645 - tversky: 0.9080 - val_loss: 0.1910 - val_tversky: 0.8880
#
# Epoch 00038: val_loss did not improve from 0.18404
# Epoch 39/100
# 176/176 [==============================] - 92s 522ms/step - loss: 0.1581 - tversky: 0.9120 - val_loss: 0.1836 - val_tversky: 0.8944
#
# Epoch 00039: val_loss improved from 0.18404 to 0.18361, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 40/100
# 176/176 [==============================] - 94s 532ms/step - loss: 0.1619 - tversky: 0.9083 - val_loss: 0.1888 - val_tversky: 0.8801
#
# Epoch 00040: val_loss did not improve from 0.18361
# Epoch 41/100
# 176/176 [==============================] - 94s 532ms/step - loss: 0.1600 - tversky: 0.9103 - val_loss: 0.1903 - val_tversky: 0.8768
#
# Epoch 00041: val_loss did not improve from 0.18361
# Epoch 42/100
# 176/176 [==============================] - 94s 533ms/step - loss: 0.1595 - tversky: 0.9109 - val_loss: 0.1796 - val_tversky: 0.8974
#
# Epoch 00042: val_loss improved from 0.18361 to 0.17957, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 43/100
# 176/176 [==============================] - 94s 531ms/step - loss: 0.1560 - tversky: 0.9138 - val_loss: 0.1816 - val_tversky: 0.8952
#
# Epoch 00043: val_loss did not improve from 0.17957
# Epoch 44/100
# 176/176 [==============================] - 93s 528ms/step - loss: 0.1533 - tversky: 0.9159 - val_loss: 0.2309 - val_tversky: 0.8536
#
# Epoch 00044: val_loss did not improve from 0.17957
# Epoch 45/100
# 176/176 [==============================] - 93s 529ms/step - loss: 0.1550 - tversky: 0.9144 - val_loss: 0.1814 - val_tversky: 0.8960
#
# Epoch 00045: val_loss did not improve from 0.17957
# Epoch 46/100
# 176/176 [==============================] - 94s 531ms/step - loss: 0.1518 - tversky: 0.9166 - val_loss: 0.1878 - val_tversky: 0.8815
#
# Epoch 00046: val_loss did not improve from 0.17957
# Epoch 47/100
# 176/176 [==============================] - 93s 527ms/step - loss: 0.1468 - tversky: 0.9213 - val_loss: 0.1820 - val_tversky: 0.8930
#
# Epoch 00047: val_loss did not improve from 0.17957
# Epoch 48/100
# 176/176 [==============================] - 93s 528ms/step - loss: 0.1479 - tversky: 0.9194 - val_loss: 0.1772 - val_tversky: 0.8984
#
# Epoch 00048: val_loss improved from 0.17957 to 0.17724, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 49/100
# 176/176 [==============================] - 94s 535ms/step - loss: 0.1488 - tversky: 0.9197 - val_loss: 0.1709 - val_tversky: 0.9037
#
# Epoch 00049: val_loss improved from 0.17724 to 0.17090, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 50/100
# 176/176 [==============================] - 93s 527ms/step - loss: 0.4494 - tversky: 0.6241 - val_loss: 0.1877 - val_tversky: 0.8912
#
# Epoch 00050: val_loss did not improve from 0.17090
# Epoch 51/100
# 176/176 [==============================] - 91s 518ms/step - loss: 0.1457 - tversky: 0.9218 - val_loss: 0.2005 - val_tversky: 0.8787
#
# Epoch 00051: val_loss did not improve from 0.17090
# Epoch 52/100
# 176/176 [==============================] - 94s 530ms/step - loss: 0.1425 - tversky: 0.9238 - val_loss: 0.1764 - val_tversky: 0.9000
#
# Epoch 00052: val_loss did not improve from 0.17090
# Epoch 53/100
# 176/176 [==============================] - 93s 528ms/step - loss: 0.1550 - tversky: 0.9125 - val_loss: 0.1725 - val_tversky: 0.9028
#
# Epoch 00053: val_loss did not improve from 0.17090
# Epoch 54/100
# 176/176 [==============================] - 92s 524ms/step - loss: 0.8495 - tversky: 0.1863 - val_loss: 0.6348 - val_tversky: 0.4481
#
# Epoch 00054: val_loss did not improve from 0.17090
# Epoch 55/100
# 176/176 [==============================] - 93s 525ms/step - loss: 0.1636 - tversky: 0.9062 - val_loss: 0.1829 - val_tversky: 0.8932
#
# Epoch 00055: val_loss did not improve from 0.17090
# Epoch 56/100
# 176/176 [==============================] - 92s 522ms/step - loss: 0.1433 - tversky: 0.9237 - val_loss: 0.1891 - val_tversky: 0.8731
#
# Epoch 00056: val_loss did not improve from 0.17090
# Epoch 57/100
# 176/176 [==============================] - 94s 534ms/step - loss: 0.1452 - tversky: 0.9216 - val_loss: 0.1959 - val_tversky: 0.8834
#
# Epoch 00057: val_loss did not improve from 0.17090
# Epoch 58/100
# 176/176 [==============================] - 93s 529ms/step - loss: 0.1497 - tversky: 0.9166 - val_loss: 0.1759 - val_tversky: 0.8990
#
# Epoch 00058: val_loss did not improve from 0.17090
# Epoch 59/100
# 176/176 [==============================] - 93s 528ms/step - loss: 0.1384 - tversky: 0.9272 - val_loss: 0.1851 - val_tversky: 0.8909
#
# Epoch 00059: val_loss did not improve from 0.17090
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 60/100
# 176/176 [==============================] - 93s 529ms/step - loss: 0.1458 - tversky: 0.9194 - val_loss: 0.1838 - val_tversky: 0.8936
#
# Epoch 00060: val_loss did not improve from 0.17090
# Epoch 61/100
# 176/176 [==============================] - 92s 520ms/step - loss: 0.1362 - tversky: 0.9280 - val_loss: 0.1638 - val_tversky: 0.9087
#
# Epoch 00061: val_loss improved from 0.17090 to 0.16378, saving model to ./Model10_Mobilennetv2Unet_BrainMriSeg.h5
# Epoch 62/100
# 176/176 [==============================] - 92s 523ms/step - loss: 0.1366 - tversky: 0.9284 - val_loss: 0.1772 - val_tversky: 0.8971
#
# Epoch 00062: val_loss did not improve from 0.16378
# Epoch 63/100
# 176/176 [==============================] - 94s 533ms/step - loss: 0.1405 - tversky: 0.9236 - val_loss: 0.1792 - val_tversky: 0.8972
#
# Epoch 00063: val_loss did not improve from 0.16378
# Epoch 64/100
# 176/176 [==============================] - 93s 529ms/step - loss: 0.1375 - tversky: 0.9259 - val_loss: 0.1796 - val_tversky: 0.8976
#
# Epoch 00064: val_loss did not improve from 0.16378
# Epoch 65/100
# 176/176 [==============================] - 93s 526ms/step - loss: 0.1351 - tversky: 0.9289 - val_loss: 0.1800 - val_tversky: 0.8969
#
# Epoch 00065: val_loss did not improve from 0.16378
# Epoch 66/100
# 176/176 [==============================] - 93s 526ms/step - loss: 0.1359 - tversky: 0.9281 - val_loss: 0.1703 - val_tversky: 0.8958
#
# Epoch 00066: val_loss did not improve from 0.16378
# Epoch 67/100
# 176/176 [==============================] - 94s 530ms/step - loss: 0.9669 - tversky: 0.0431 - val_loss: 0.1660 - val_tversky: 0.8992
#
# Epoch 00067: val_loss did not improve from 0.16378
# Epoch 68/100
# 176/176 [==============================] - 93s 527ms/step - loss: 0.1379 - tversky: 0.9267 - val_loss: 0.1831 - val_tversky: 0.8944
#
# Epoch 00068: val_loss did not improve from 0.16378
# Epoch 69/100
# 176/176 [==============================] - 94s 530ms/step - loss: 0.1374 - tversky: 0.9263 - val_loss: 0.1801 - val_tversky: 0.8883
#
# Epoch 00069: val_loss did not improve from 0.16378
# Epoch 70/100
# 176/176 [==============================] - 93s 527ms/step - loss: 0.1420 - tversky: 0.9216 - val_loss: 0.1639 - val_tversky: 0.9077
#
# Epoch 00070: val_loss did not improve from 0.16378
# Epoch 71/100
# 176/176 [==============================] - 92s 522ms/step - loss: 0.1339 - tversky: 0.9291 - val_loss: 0.1893 - val_tversky: 0.8722
#
# Epoch 00071: val_loss did not improve from 0.16378
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 72/100
# 176/176 [==============================] - 93s 525ms/step - loss: 0.1344 - tversky: 0.9294 - val_loss: 0.1688 - val_tversky: 0.9040
#
# Epoch 00072: val_loss did not improve from 0.16378
# Epoch 73/100
# 176/176 [==============================] - 94s 533ms/step - loss: 0.1384 - tversky: 0.9244 - val_loss: 0.1728 - val_tversky: 0.9030
#
# Epoch 00073: val_loss did not improve from 0.16378
# Epoch 74/100
# 176/176 [==============================] - 93s 529ms/step - loss: 0.1373 - tversky: 0.9271 - val_loss: 0.1789 - val_tversky: 0.8954
#
# Epoch 00074: val_loss did not improve from 0.16378
# Epoch 75/100
# 176/176 [==============================] - 93s 528ms/step - loss: 0.1313 - tversky: 0.9322 - val_loss: 0.1780 - val_tversky: 0.8978
#
# Epoch 00075: val_loss did not improve from 0.16378
# Epoch 76/100
# 176/176 [==============================] - 94s 533ms/step - loss: 0.1378 - tversky: 0.9244 - val_loss: 0.1840 - val_tversky: 0.8932
#
# Epoch 00076: val_loss did not improve from 0.16378
# Epoch 77/100
# 176/176 [==============================] - 93s 527ms/step - loss: 0.1336 - tversky: 0.9303 - val_loss: 0.1692 - val_tversky: 0.9044
#
# Epoch 00077: val_loss did not improve from 0.16378
# Epoch 78/100
# 176/176 [==============================] - 93s 527ms/step - loss: 0.1348 - tversky: 0.9294 - val_loss: 0.1730 - val_tversky: 0.9000
#
# Epoch 00078: val_loss did not improve from 0.16378
# Epoch 79/100
# 176/176 [==============================] - 94s 534ms/step - loss: 0.1390 - tversky: 0.9248 - val_loss: 0.1924 - val_tversky: 0.8827
#
# Epoch 00079: val_loss did not improve from 0.16378
# Epoch 80/100
# 176/176 [==============================] - 94s 532ms/step - loss: 0.1326 - tversky: 0.9309 - val_loss: 0.1745 - val_tversky: 0.9001
#
# Epoch 00080: val_loss did not improve from 0.16378
# Epoch 81/100
# 176/176 [==============================] - 95s 536ms/step - loss: 0.1425 - tversky: 0.9207 - val_loss: 0.1674 - val_tversky: 0.9068
#
# Epoch 00081: val_loss did not improve from 0.16378
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 82/100
# 176/176 [==============================] - 94s 531ms/step - loss: 0.1360 - tversky: 0.9273 - val_loss: 0.1789 - val_tversky: 0.8969
#
# Epoch 00082: val_loss did not improve from 0.16378
# Epoch 83/100
# 176/176 [==============================] - 92s 520ms/step - loss: 0.1359 - tversky: 0.9274 - val_loss: 0.1679 - val_tversky: 0.9060
#
# Epoch 00083: val_loss did not improve from 0.16378
# Epoch 84/100
# 176/176 [==============================] - 93s 529ms/step - loss: 0.1347 - tversky: 0.9293 - val_loss: 0.1772 - val_tversky: 0.8927
#
# Epoch 00084: val_loss did not improve from 0.16378
# Epoch 85/100
# 176/176 [==============================] - 93s 530ms/step - loss: 0.1366 - tversky: 0.9275 - val_loss: 0.1846 - val_tversky: 0.8872
#
# Epoch 00085: val_loss did not improve from 0.16378
# Epoch 86/100
# 176/176 [==============================] - 94s 532ms/step - loss: 0.9676 - tversky: 0.0423 - val_loss: 0.1761 - val_tversky: 0.8976
#
# Epoch 00086: val_loss did not improve from 0.16378
# Epoch 87/100
# 176/176 [==============================] - 94s 532ms/step - loss: 0.1369 - tversky: 0.9273 - val_loss: 0.1762 - val_tversky: 0.9002
#
# Epoch 00087: val_loss did not improve from 0.16378
# Epoch 88/100
# 176/176 [==============================] - 94s 535ms/step - loss: 0.1305 - tversky: 0.9328 - val_loss: 0.1917 - val_tversky: 0.8849
#
# Epoch 00088: val_loss did not improve from 0.16378
# Epoch 89/100
# 176/176 [==============================] - 92s 520ms/step - loss: 0.1511 - tversky: 0.9118 - val_loss: 0.1688 - val_tversky: 0.9039
#
# Epoch 00089: val_loss did not improve from 0.16378
# Epoch 90/100
# 176/176 [==============================] - 94s 531ms/step - loss: 0.1339 - tversky: 0.9296 - val_loss: 0.1821 - val_tversky: 0.8902
#
# Epoch 00090: val_loss did not improve from 0.16378
# Epoch 91/100
# 176/176 [==============================] - 94s 536ms/step - loss: 0.1346 - tversky: 0.9292 - val_loss: 0.1774 - val_tversky: 0.8918
#
# Epoch 00091: val_loss did not improve from 0.16378
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 00091: early stopping

# %% [markdown]
# ## Model Evaluation

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'tversky', 'val_loss', 'val_tversky', 'lr'])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss']);
plt.plot(history.history['val_loss']);
plt.title("SEG Model focal tversky Loss");
plt.ylabel("focal tversky loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(history.history['tversky']);
plt.plot(history.history['val_tversky']);
plt.title("SEG Model tversky score");
plt.ylabel("tversky Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %% [markdown]
# ## Segmantation Model Performance

# %%
test_gen = train_generator(df_test, BATCH_SIZE, dict(rescale=1.0/255.0), target_size=(im_height, im_width))
results = mobile_unet.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 24/24 [==============================] - 7s 300ms/step - loss: 0.1641 - tversky: 0.9070

# %%
for i in range(30):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['filename'].iloc[index])
    img = cv2.resize(img ,(im_height, im_width))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred= mobile_unet.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
