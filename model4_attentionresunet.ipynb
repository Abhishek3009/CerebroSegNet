# %% [markdown]
# # **Attention ResUnet**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from skimage import io

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import Conv2D, Convolution2D, BatchNormalization, Activation, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, MaxPooling2D, AveragePooling2D, UpSampling2D, Dropout, ZeroPadding2D
from tensorflow.keras.layers import Add, Lambda, ReLU, LeakyReLU, concatenate
from tensorflow.keras.applications import MobileNetV2

from warnings import filterwarnings
filterwarnings('ignore')
import random
from glob import glob
from IPython.display import display

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1
# 2022-07-04 14:16:47.403635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-04 14:16:47.562027: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-04 14:16:47.562897: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# # Prepare dataset

# %%
#Set Parameters
im_width = 256
im_height = 256

# %% [markdown]
# # **Load image's path and mask's path**

# %%
train_files = []
mask_files = glob('../input/lgg-mri-segmentation/kaggle_3m/*/*_mask*')

for i in mask_files:
    train_files.append(i.replace('_mask',''))

print(train_files[:10])
print(mask_files[:10])
# Out:
# ['../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_8.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_34.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_33.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_43.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_39.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_7.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_31.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_6.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_38.tif']
# ['../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_8_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_34_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_33_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_43_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_39_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_7_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_31_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_6_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_38_mask.tif']

# %% [markdown]
# # **Data Visualization**

# %%
#Lets plot some samples
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=train_files[i]
    msk_path=mask_files[i]
    img=cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %% [markdown]
# ## **Create data frame and split data on train set, validation set and test set**

# %%
df = pd.DataFrame(data={"filename": train_files, 'mask' : mask_files})
df_train, df_test = train_test_split(df,test_size = 0.1)
df_train, df_val = train_test_split(df_train,test_size = 0.2)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (2828, 2)
# (708, 2)
# (393, 2)

# %% [markdown]
# ## **Data genertator, data augmentation and adjust data**

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)

    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)

    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0

    return (img, mask)

# %% [markdown]
# ## **Model**

# %%
def gating_signal(input, out_size, batch_norm=False):
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def conv_block(x, filter_size, size, dropout, batch_norm=False):
    """
    Convolutional Block
    """
    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same", kernel_initializer='he_normal')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same", kernel_initializer='he_normal')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv

def repeat_elem(tensor, rep):
    """
    Repeating elements along axis
    """
    return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),arguments={'repnum': rep})(tensor)

# %%
def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

    # Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

    # Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

# %%
def Attention_UNet(input_shape, NUM_CLASSES=1, dropout_rate=0.0, batch_norm=True):
    '''
    Attention UNet
    '''
    # network structure
    FILTER_NUM = 64 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters

    inputs = layers.Input(input_shape, dtype=tf.float32)

    # Downsampling layers
    # DownRes 1, convolution + pooling
    conv_128 = conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = conv_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = conv_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5, convolution only
    conv_8 = conv_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers
    # UpRes 6, attention gated concatenation + upsampling + double residual convolution
    gating_16 = gating_signal(conv_8, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=3)
    up_conv_16 = conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7
    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(conv_32, gating_32, 4*FILTER_NUM)
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=3)
    up_conv_32 = conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=3)
    up_conv_64 = conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(conv_128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=3)
    up_conv_128 = conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  #Change to softmax for multichannel

    # Model integration
    model = tf.keras.Model(inputs, conv_final, name="Attention_UNet")
    return model

# %%
img_height = 256
img_width = 256
num_channels = 3

attunet = Attention_UNet((img_height, img_width, num_channels), NUM_CLASSES=1, dropout_rate=0.0, batch_norm=True)
attunet.summary()
# Out:
# 2022-07-04 14:16:50.048906: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-04 14:16:50.049371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-04 14:16:50.050219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-04 14:16:50.050871: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-04 14:16:52.384620: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-04 14:16:52.385756: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-04 14:16:52.386758: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-04 14:16:52.387749: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "Attention_UNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 512)  2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 512)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 1024) 4096        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 1024) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 1024) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 512)  524800      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 512)  262656      activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 512)  2359808     conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 512)  1049088     activation_7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 512)  0           conv2d_transpose[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 512)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 1)    513         activation_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 1)    0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 32, 32, 512)  0           up_sampling2d[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 32, 32, 512)  0           lambda[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 512)  262656      multiply[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 1024) 0           activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1536) 0           up_sampling2d_1[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 512)  7078400     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 512)  2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 512)  2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 512)  2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 512)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 256)  131328      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 256)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 256)  65792       activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 256)  590080      conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 256)  262400      activation_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 1)    257         activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 1)    0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 1)    0           activation_17[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 64, 64, 256)  0           up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 64, 64, 256)  0           lambda_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 256)  65792       multiply_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 512)  0           activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 256)  1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 768)  0           up_sampling2d_3[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 256)  1769728     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 256)  1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 256)  590080      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 256)  1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 128)  32896       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 128)  512         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 64, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 128)  16512       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 128)  147584      conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 128)  65664       activation_3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 64, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 1)    129         activation_21[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 1)    0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 1)  0           activation_22[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 128, 128, 128 0           up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 128, 128, 128 0           lambda_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 128, 128, 128 16512       multiply_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 256 0           activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 128, 128, 128 512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 384 0           up_sampling2d_5[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 128, 128, 128 442496      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 128, 128, 128 512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 128, 128, 128 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 128, 128, 128 147584      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 128, 128, 128 512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 128, 128, 128 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 128, 128, 64) 8256        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 128, 64) 256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 128, 128, 64) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 128, 128, 64) 4160        activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 64) 36928       conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 128, 128, 64) 16448       activation_1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 128, 64) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 128, 128, 64) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 128, 128, 1)  65          activation_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 128, 128, 1)  0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 256, 256, 1)  0           activation_27[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 256, 256, 64) 0           up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 256, 256, 64) 0           lambda_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 256, 256, 64) 4160        multiply_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 128 0           activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 256, 256, 64) 256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 192 0           up_sampling2d_7[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 256, 256, 64) 110656      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 256, 256, 64) 256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 256, 256, 64) 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 256, 256, 64) 36928       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 256, 256, 64) 256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 256, 256, 64) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 256, 256, 1)  65          activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 256, 256, 1)  4           conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 256, 256, 1)  0           batch_normalization_26[0][0]
# ==================================================================================================
# Total params: 37,334,665
# Trainable params: 37,319,047
# Non-trainable params: 15,618
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import backend as K
EPOCHS = 100
BATCH_SIZE = 16
learning_rate = 0.01

# %%
epsilon = 1e-5
smooth = 1

def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def focal_tversky(y_true,y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    pt_1 = tversky(y_true, y_pred)
    gamma = 0.75
    return K.pow((1-pt_1), gamma)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

# %%
# compling model and callbacks functions
adam = tf.keras.optimizers.Adam(learning_rate = learning_rate, epsilon = 0.1)
attunet.compile(optimizer = adam,
                  loss = focal_tversky,
                  metrics = [tversky]
                 )
#callbacks
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=30
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="./Model4_AttentionUnet_BrainMriSeg.h5",
                               verbose=1,
                               save_best_only=True
                              )
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=10,
                              min_delta=0.0001,
                              factor=0.2
                             )

# %%
train_generator_args = dict(width_shift_range=0.05,
                            height_shift_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            vertical_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=(im_height, im_width))

val_gen = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
history = attunet.fit(train_gen,
                  epochs = EPOCHS,
                  steps_per_epoch=len(df_train) / BATCH_SIZE,
                  validation_data = val_gen,
                  validation_steps=len(df_val) / BATCH_SIZE,
                  callbacks = [checkpointer, earlystopping, reduce_lr])
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# 2022-07-04 14:16:56.265580: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-07-04 14:17:01.509821: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
#
saving model to ./Model4_AttentionUnet_BrainMriSeg.h5
# Epoch 32/100
# 176/176 [==============================] - 121s 686ms/step - loss: 0.2139 - tversky: 0.8669 - val_loss: 0.1836 - val_tversky: 0.8784
#
# Epoch 00032: val_loss improved from 0.23026 to 0.18357, saving model to ./Model4_AttentionUnet_BrainMriSeg.h5
# Epoch 33/100
# 176/176 [==============================] - 118s 668ms/step - loss: 0.2010 - tversky: 0.8792 - val_loss: 0.1897 - val_tversky: 0.8890
#
# Epoch 00033: val_loss did not improve from 0.18357
# Epoch 34/100
# 176/176 [==============================] - 119s 672ms/step - loss: 0.1985 - tversky: 0.8796 - val_loss: 0.1847 - val_tversky: 0.8922
#
# Epoch 00034: val_loss did not improve from 0.18357
# Epoch 35/100
# 176/176 [==============================] - 118s 669ms/step - loss: 0.1960 - tversky: 0.8836 - val_loss: 0.1950 - val_tversky: 0.8673
#
# Epoch 00035: val_loss did not improve from 0.18357
# Epoch 36/100
# 176/176 [==============================] - 118s 669ms/step - loss: 0.1995 - tversky: 0.8791 - val_loss: 0.1800 - val_tversky: 0.8899
#
# Epoch 00036: val_loss improved from 0.18357 to 0.18000, saving model to ./Model4_AttentionUnet_BrainMriSeg.h5
# Epoch 37/100
# 176/176 [==============================] - 121s 684ms/step - loss: 0.1932 - tversky: 0.8844 - val_loss: 0.1818 - val_tversky: 0.8941
#
# Epoch 00037: val_loss did not improve from 0.18000
# Epoch 38/100
# 176/176 [==============================] - 125s 709ms/step - loss: 0.1886 - tversky: 0.8888 - val_loss: 0.1790 - val_tversky: 0.8814
#
# Epoch 00038: val_loss improved from 0.18000 to 0.17900, saving model to ./Model4_AttentionUnet_BrainMriSeg.h5
# Epoch 39/100
# 176/176 [==============================] - 121s 683ms/step - loss: 0.1912 - tversky: 0.8876 - val_loss: 0.1679 - val_tversky: 0.9058
#
# Epoch 00039: val_loss improved from 0.17900 to 0.16788, saving model to ./Model4_AttentionUnet_BrainMriSeg.h5
# Epoch 40/100
# 176/176 [==============================] - 119s 673ms/step - loss: 0.1972 - tversky: 0.8812 - val_loss: 0.1674 - val_tversky: 0.9064
#
# Epoch 00040: val_loss improved from 0.16788 to 0.16744, saving model to ./Model4_AttentionUnet_BrainMriSeg.h5
# Epoch 41/100
# 176/176 [==============================] - 122s 689ms/step - loss: 0.1893 - tversky: 0.8883 - val_loss: 0.1690 - val_tversky: 0.9048
#
# Epoch 00041: val_loss did not improve from 0.16744
# Epoch 42/100
# 176/176 [==============================] - 118s 669ms/step - loss: 0.1855 - tversky: 0.8916 - val_loss: 0.1675 - val_tversky: 0.8891
#
# Epoch 00042: val_loss did not improve from 0.16744
# Epoch 43/100
# 176/176 [==============================] - 121s 682ms/step - loss: 0.1874 - tversky: 0.8879 - val_loss: 0.1712 - val_tversky: 0.9032
#
# Epoch 00043: val_loss did not improve from 0.16744
# Epoch 44/100
# 176/176 [==============================] - 122s 691ms/step - loss: 0.1830 - tversky: 0.8929 - val_loss: 0.1727 - val_tversky: 0.9021
#
# Epoch 00044: val_loss did not improve from 0.16744
# Epoch 45/100
# 176/176 [==============================] - 121s 685ms/step - loss: 0.1765 - tversky: 0.8989 - val_loss: 0.1959 - val_tversky: 0.8798
#
# Epoch 00045: val_loss did not improve from 0.16744
# Epoch 46/100
# 176/176 [==============================] - 118s 670ms/step - loss: 0.1788 - tversky: 0.8970 - val_loss: 0.1713 - val_tversky: 0.9029
#
# Epoch 00046: val_loss did not improve from 0.16744
# Epoch 47/100
# 176/176 [==============================] - 120s 680ms/step - loss: 0.1872 - tversky: 0.8891 - val_loss: 0.1711 - val_tversky: 0.9031
#
# Epoch 00047: val_loss did not improve from 0.16744
# Epoch 48/100
# 176/176 [==============================] - 119s 671ms/step - loss: 0.1857 - tversky: 0.8912 - val_loss: 0.1934 - val_tversky: 0.8826
#
# Epoch 00048: val_loss did not improve from 0.16744
# Epoch 49/100
# 176/176 [==============================] - 119s 673ms/step - loss: 0.1879 - tversky: 0.8868 - val_loss: 0.1754 - val_tversky: 0.8992
#
# Epoch 00049: val_loss did not improve from 0.16744
# Epoch 50/100
# 176/176 [==============================] - 119s 672ms/step - loss: 0.1815 - tversky: 0.8950 - val_loss: 0.1670 - val_tversky: 0.8916
#
# Epoch 00050: val_loss improved from 0.16744 to 0.16698, saving model to ./Model4_AttentionUnet_BrainMriSeg.h5
# Epoch 51/100
# 176/176 [==============================] - 121s 685ms/step - loss: 0.1803 - tversky: 0.8953 - val_loss: 0.1648 - val_tversky: 0.9087
#
# Epoch 00051: val_loss improved from 0.16698 to 0.16477, saving model to ./Model4_AttentionUnet_BrainMriSeg.h5
# Epoch 52/100
# 176/176 [==============================] - 119s 673ms/step - loss: 0.1775 - tversky: 0.8976 - val_loss: 0.1693 - val_tversky: 0.9042
#
# Epoch 00052: val_loss did not improve from 0.16477
# Epoch 53/100
# 176/176 [==============================] - 119s 676ms/step - loss: 0.1731 - tversky: 0.9014 - val_loss: 0.1954 - val_tversky: 0.8776
#
# Epoch 00053: val_loss did not improve from 0.16477
# Epoch 54/100
# 176/176 [==============================] - 121s 687ms/step - loss: 0.1755 - tversky: 0.8990 - val_loss: 0.1739 - val_tversky: 0.9010
#
# Epoch 00054: val_loss did not improve from 0.16477
# Epoch 55/100
# 176/176 [==============================] - 123s 694ms/step - loss: 0.1759 - tversky: 0.8993 - val_loss: 0.1612 - val_tversky: 0.9104
#
# Epoch 00055: val_loss improved from 0.16477 to 0.16124, saving model to ./Model4_AttentionUnet_BrainMriSeg.h5
# Epoch 56/100
# 176/176 [==============================] - 119s 676ms/step - loss: 0.1734 - tversky: 0.8998 - val_loss: 0.1818 - val_tversky: 0.8800
#
# Epoch 00056: val_loss did not improve from 0.16124
# Epoch 57/100
# 176/176 [==============================] - 119s 672ms/step - loss: 0.1755 - tversky: 0.8990 - val_loss: 0.1520 - val_tversky: 0.9180
#
# Epoch 00057: val_loss improved from 0.16124 to 0.15195, saving model to ./Model4_AttentionUnet_BrainMriSeg.h5
# Epoch 58/100
# 176/176 [==============================] - 119s 673ms/step - loss: 0.1801 - tversky: 0.8954 - val_loss: 0.1634 - val_tversky: 0.9070
#
# Epoch 00058: val_loss did not improve from 0.15195
# Epoch 59/100
# 176/176 [==============================] - 120s 677ms/step - loss: 0.1779 - tversky: 0.8971 - val_loss: 0.1840 - val_tversky: 0.8875
#
# Epoch 00059: val_loss did not improve from 0.15195
# Epoch 60/100
# 176/176 [==============================] - 122s 691ms/step - loss: 0.1704 - tversky: 0.9032 - val_loss: 0.1645 - val_tversky: 0.9017
#
# Epoch 00060: val_loss did not improve from 0.15195
# Epoch 61/100
# 176/176 [==============================] - 118s 670ms/step - loss: 0.1770 - tversky: 0.8960 - val_loss: 0.1591 - val_tversky: 0.9116
#
# Epoch 00061: val_loss did not improve from 0.15195
# Epoch 62/100
# 176/176 [==============================] - 119s 672ms/step - loss: 0.1718 - tversky: 0.9015 - val_loss: 0.1745 - val_tversky: 0.8941
#
# Epoch 00062: val_loss did not improve from 0.15195
# Epoch 63/100
# 176/176 [==============================] - 119s 675ms/step - loss: 0.1725 - tversky: 0.9009 - val_loss: 0.1829 - val_tversky: 0.8741
#
# Epoch 00063: val_loss did not improve from 0.15195
# Epoch 64/100
# 176/176 [==============================] - 121s 686ms/step - loss: 0.1759 - tversky: 0.8970 - val_loss: 0.1828 - val_tversky: 0.8770
#
# Epoch 00064: val_loss did not improve from 0.15195
# Epoch 65/100
# 176/176 [==============================] - 119s 674ms/step - loss: 0.1696 - tversky: 0.9037 - val_loss: 0.1823 - val_tversky: 0.8900
#
# Epoch 00065: val_loss did not improve from 0.15195
# Epoch 66/100
# 176/176 [==============================] - 122s 691ms/step - loss: 0.1669 - tversky: 0.9058 - val_loss: 0.1644 - val_tversky: 0.9076
#
# Epoch 00066: val_loss did not improve from 0.15195
# Epoch 67/100
# 176/176 [==============================] - 120s 677ms/step - loss: 0.1712 - tversky: 0.9007 - val_loss: 0.1637 - val_tversky: 0.8933
#
# Epoch 00067: val_loss did not improve from 0.15195
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# Epoch 68/100
# 176/176 [==============================] - 119s 675ms/step - loss: 0.1698 - tversky: 0.9016 - val_loss: 0.1794 - val_tversky: 0.8856
#
# Epoch 00068: val_loss did not improve from 0.15195
# Epoch 69/100
# 176/176 [==============================] - 122s 689ms/step - loss: 0.1642 - tversky: 0.9058 - val_loss: 0.1518 - val_tversky: 0.9168
#
# Epoch 00069: val_loss improved from 0.15195 to 0.15182, saving model to ./Model4_AttentionUnet_BrainMriSeg.h5
# Epoch 70/100
# 176/176 [==============================] - 120s 677ms/step - loss: 0.1601 - tversky: 0.9110 - val_loss: 0.1640 - val_tversky: 0.8916
#
# Epoch 00070: val_loss did not improve from 0.15182
# Epoch 71/100
# 176/176 [==============================] - 120s 678ms/step - loss: 0.1606 - tversky: 0.9109 - val_loss: 0.1541 - val_tversky: 0.9165
#
# Epoch 00071: val_loss did not improve from 0.15182
# Epoch 72/100
# 176/176 [==============================] - 122s 688ms/step - loss: 0.1705 - tversky: 0.9011 - val_loss: 0.1463 - val_tversky: 0.9220
#
# Epoch 00072: val_loss improved from 0.15182 to 0.14628, saving model to ./Model4_AttentionUnet_BrainMriSeg.h5
# Epoch 73/100
# 176/176 [==============================] - 121s 687ms/step - loss: 0.1635 - tversky: 0.9075 - val_loss: 0.1661 - val_tversky: 0.8920
#
# Epoch 00073: val_loss did not improve from 0.14628
# Epoch 74/100
# 176/176 [==============================] - 122s 692ms/step - loss: 0.1588 - tversky: 0.9119 - val_loss: 0.1708 - val_tversky: 0.8970
#
# Epoch 00074: val_loss did not improve from 0.14628
# Epoch 75/100
# 176/176 [==============================] - 119s 673ms/step - loss: 0.1562 - tversky: 0.9142 - val_loss: 0.1542 - val_tversky: 0.9159
#
# Epoch 00075: val_loss did not improve from 0.14628
# Epoch 76/100
# 176/176 [==============================] - 122s 688ms/step - loss: 0.1593 - tversky: 0.9118 - val_loss: 0.1694 - val_tversky: 0.8899
#
# Epoch 00076: val_loss did not improve from 0.14628
# Epoch 77/100
# 176/176 [==============================] - 122s 690ms/step - loss: 0.1606 - tversky: 0.9101 - val_loss: 0.1658 - val_tversky: 0.9066
#
# Epoch 00077: val_loss did not improve from 0.14628
# Epoch 78/100
# 176/176 [==============================] - 119s 673ms/step - loss: 0.1632 - tversky: 0.9078 - val_loss: 0.1521 - val_tversky: 0.9177
#
# Epoch 00078: val_loss did not improve from 0.14628
# Epoch 79/100
# 176/176 [==============================] - 122s 693ms/step - loss: 0.1581 - tversky: 0.9127 - val_loss: 0.1635 - val_tversky: 0.8943
#
# Epoch 00079: val_loss did not improve from 0.14628
# Epoch 80/100
# 176/176 [==============================] - 122s 693ms/step - loss: 0.1566 - tversky: 0.9140 - val_loss: 0.1590 - val_tversky: 0.9129
#
# Epoch 00080: val_loss did not improve from 0.14628
# Epoch 81/100
# 176/176 [==============================] - 121s 686ms/step - loss: 0.1603 - tversky: 0.9102 - val_loss: 0.1581 - val_tversky: 0.9129
#
# Epoch 00081: val_loss did not improve from 0.14628
# Epoch 82/100
# 176/176 [==============================] - 122s 690ms/step - loss: 0.1548 - tversky: 0.9156 - val_loss: 0.1523 - val_tversky: 0.9029
#
# Epoch 00082: val_loss did not improve from 0.14628
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# Epoch 83/100
# 176/176 [==============================] - 120s 678ms/step - loss: 0.1591 - tversky: 0.9116 - val_loss: 0.1572 - val_tversky: 0.9124
#
# Epoch 00083: val_loss did not improve from 0.14628
# Epoch 84/100
# 176/176 [==============================] - 122s 690ms/step - loss: 0.1618 - tversky: 0.9100 - val_loss: 0.1530 - val_tversky: 0.9166
#
# Epoch 00084: val_loss did not improve from 0.14628
# Epoch 85/100
# 176/176 [==============================] - 120s 678ms/step - loss: 0.1589 - tversky: 0.9116 - val_loss: 0.1588 - val_tversky: 0.9122
#
# Epoch 00085: val_loss did not improve from 0.14628
# Epoch 86/100
# 176/176 [==============================] - 122s 693ms/step - loss: 0.1597 - tversky: 0.9109 - val_loss: 0.1607 - val_tversky: 0.8965
#
# Epoch 00086: val_loss did not improve from 0.14628
# Epoch 87/100
# 176/176 [==============================] - 119s 672ms/step - loss: 0.1610 - tversky: 0.9100 - val_loss: 0.1579 - val_tversky: 0.9104
#
# Epoch 00087: val_loss did not improve from 0.14628
# Epoch 88/100
# 176/176 [==============================] - 120s 680ms/step - loss: 0.1540 - tversky: 0.9157 - val_loss: 0.1846 - val_tversky: 0.8745
#
# Epoch 00088: val_loss did not improve from 0.14628
# Epoch 89/100
# 176/176 [==============================] - 119s 676ms/step - loss: 0.1563 - tversky: 0.9131 - val_loss: 0.1810 - val_tversky: 0.8720
#
# Epoch 00089: val_loss did not improve from 0.14628
# Epoch 90/100
# 176/176 [==============================] - 119s 674ms/step - loss: 0.1634 - tversky: 0.9067 - val_loss: 0.1506 - val_tversky: 0.9185
#
# Epoch 00090: val_loss did not improve from 0.14628
# Epoch 91/100
# 176/176 [==============================] - 123s 694ms/step - loss: 0.1598 - tversky: 0.9104 - val_loss: 0.1508 - val_tversky: 0.9172
#
# Epoch 00091: val_loss did not improve from 0.14628
# Epoch 92/100
# 176/176 [==============================] - 123s 694ms/step - loss: 0.1549 - tversky: 0.9143 - val_loss: 0.1690 - val_tversky: 0.8996
#
# Epoch 00092: val_loss did not improve from 0.14628
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# Epoch 93/100
# 176/176 [==============================] - 122s 692ms/step - loss: 0.9640 - tversky: 0.0470 - val_loss: 0.1543 - val_tversky: 0.9149
#
# Epoch 00093: val_loss did not improve from 0.14628
# Epoch 94/100
# 176/176 [==============================] - 119s 676ms/step - loss: 0.1592 - tversky: 0.9116 - val_loss: 0.1559 - val_tversky: 0.9142
#
# Epoch 00094: val_loss did not improve from 0.14628
# Epoch 95/100
# 176/176 [==============================] - 119s 675ms/step - loss: 0.1529 - tversky: 0.9169 - val_loss: 0.1588 - val_tversky: 0.9134
#
# Epoch 00095: val_loss did not improve from 0.14628
# Epoch 96/100
# 176/176 [==============================] - 122s 690ms/step - loss: 0.1613 - tversky: 0.9088 - val_loss: 0.1597 - val_tversky: 0.9099
#
# Epoch 00096: val_loss did not improve from 0.14628
# Epoch 97/100
# 176/176 [==============================] - 122s 693ms/step - loss: 0.1558 - tversky: 0.9146 - val_loss: 0.1559 - val_tversky: 0.9144
#
# Epoch 00097: val_loss did not improve from 0.14628
# Epoch 98/100
# 176/176 [==============================] - 120s 678ms/step - loss: 0.1587 - tversky: 0.9120 - val_loss: 0.1598 - val_tversky: 0.9107
#
# Epoch 00098: val_loss did not improve from 0.14628
# Epoch 99/100
# 176/176 [==============================] - 122s 693ms/step - loss: 0.1566 - tversky: 0.9128 - val_loss: 0.1582 - val_tversky: 0.9125
#
# Epoch 00099: val_loss did not improve from 0.14628
# Epoch 100/100
# 176/176 [==============================] - 120s 682ms/step - loss: 0.1596 - tversky: 0.9099 - val_loss: 0.1565 - val_tversky: 0.9143
#
# Epoch 00100: val_loss did not improve from 0.14628

# %% [markdown]
# ## Model Evaluation

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'tversky', 'val_loss', 'val_tversky', 'lr'])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss']);
plt.plot(history.history['val_loss']);
plt.title("SEG Model focal tversky Loss");
plt.ylabel("focal tversky loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(history.history['tversky']);
plt.plot(history.history['val_tversky']);
plt.title("SEG Model tversky score");
plt.ylabel("tversky Accuracy");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %% [markdown]
# ## Segmantation Model Performance

# %%
attunet = load_model("./Model4_AttentionUnet_BrainMriSeg.h5",custom_objects={"focal_tversky":focal_tversky,"tversky":tversky,"tversky_loss":tversky_loss})

# %%
test_gen = train_generator(df_test, BATCH_SIZE, dict(), target_size=(im_height, im_width))
results = attunet.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 24/24 [==============================] - 7s 242ms/step - loss: 0.1600 - tversky: 0.9116

# %%
for i in range(30):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['filename'].iloc[index])
    img = cv2.resize(img ,(im_height, im_width))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred= attunet.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
